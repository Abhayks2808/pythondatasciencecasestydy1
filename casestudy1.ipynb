# %% [markdown]
# # Case study 1:-

# %%
#import the customer data into python

# %%
import pandas as pd

# %%
customer=pd.read_csv('Customers.csv',encoding='ISO-8859-1')

# %%
#2.	Understand the data using different functions and attributes like shape, index, columns, dtypes.ndim, 
#info(), get_dtype_counts etc.

# %%
customer.shape
# Out:
# (10000, 14)

# %%
customer.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
customer.columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %%
customer.dtypes.ndim
# Out:
# 1

# %% [raw]
# customer.info()

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      10000 non-null  int64
#  1   Gender           9986 non-null   object
#  2   First_Date       10000 non-null  int64
#  3   First_region     9979 non-null   object
#  4   First_state      9983 non-null   object
#  5   First_city       10000 non-null  object
#  6   Recent_Date      10000 non-null  int64
#  7   Last_region      10000 non-null  object
#  8   Last_state       10000 non-null  object
#  9   Last_city        10000 non-null  object
#  10  Customer_Value   9964 non-null   float64
#  11  Buy_Times        10000 non-null  int64
#  12  Points_Earned    9979 non-null   float64
#  13  Points_Redeemed  9988 non-null   float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
customer.info
# Out:
# <bound method DataFrame.info of       Customer_ID Gender  First_Date First_region    First_state  \
# 0       129609144      M    20130130         West        Gujarat
# 1       129627580      M    20130129        North          Delhi
# 2       130363481      M    20130221         West        Gujarat
# 3        49817480      M    20130222         West    Maharashtra
# 4       126343829      F    20130301        North          Delhi
# ...           ...    ...         ...          ...            ...
# 9995     50093138      M    20120208        North  Uttar Pradesh
# 9996     92763145      M    20120209        South      Telangana
# 9997     73839417      M    20120210        South      Karnataka
# 9998     69606859      M    20120215        North  Uttar Pradesh
# 9999    113292109      M    20120217         West    Maharashtra
#
#             First_city  Recent_Date Last_region     Last_state  \
# 0                Surat     20130216        West        Gujarat
# ...

# %%
customer.describe
# Out:
# <bound method NDFrame.describe of       Customer_ID Gender  First_Date First_region    First_state  \
# 0       129609144      M    20130130         West        Gujarat
# 1       129627580      M    20130129        North          Delhi
# 2       130363481      M    20130221         West        Gujarat
# 3        49817480      M    20130222         West    Maharashtra
# 4       126343829      F    20130301        North          Delhi
# ...           ...    ...         ...          ...            ...
# 9995     50093138      M    20120208        North  Uttar Pradesh
# 9996     92763145      M    20120209        South      Telangana
# 9997     73839417      M    20120210        South      Karnataka
# 9998     69606859      M    20120215        North  Uttar Pradesh
# 9999    113292109      M    20120217         West    Maharashtra
#
#             First_city  Recent_Date Last_region     Last_state  \
# 0                Surat     20130216        West        Gujarat
# ...

# %%
customer.describe()
# Out:
#         Customer_ID    First_Date   Recent_Date  Customer_Value     Buy_Times  \
# count  1.000000e+04  1.000000e+04  1.000000e+04    9.964000e+03  10000.000000
# mean   8.347904e+07  2.012199e+07  2.012537e+07    1.254489e+04      5.477600
# std    4.802529e+07  3.424373e+03  4.744995e+03    6.546771e+04     11.677831
# min    5.850000e+02  2.012010e+07  2.012010e+07    0.000000e+00      1.000000
# 25%    3.617353e+07  2.012023e+07  2.012082e+07    1.484500e+03      1.000000
# 50%    1.146933e+08  2.012070e+07  2.012122e+07    3.960001e+03      2.000000
# 75%    1.216234e+08  2.012111e+07  2.013030e+07    1.113600e+04      6.000000
# max    1.324735e+08  2.013033e+07  2.013033e+07    5.098715e+06    586.000000
#
#        Points_Earned  Points_Redeemed
# count    9979.000000     9.988000e+03
# mean      529.355747     5.822111e+02
# std      1861.315677     1.521278e+04
# min         0.000000     0.000000e+00
# 25%        65.000000     0.000000e+00
# ...

# %%
#what is the percentage of missing values for customer value variable

# %%
((customer['Customer_Value'].isnull().value_counts()[1])/customer['Customer_Value'].count())*100
# Out:
# 0.3613006824568446

# %%
#create two subsets with unique and duplicate values

# %%
#duplicate subset

# %%
dup=customer[customer.duplicated()]

# %%
dup.head()
# Out:
#       Customer_ID Gender  First_Date First_region  First_state First_city  \
# 9973     88092811      M    20120116         West      Gujarat      Surat
# 9974     84750517      F    20120119         West      Gujarat      Surat
# 9975      5686217      M    20120118         West  Maharashtra      Thane
# 9976     63669926      M    20120118        South    Telangana  Hyderabad
# 9977     90964885      M    20120121         West      Gujarat      Surat
#
#       Recent_Date Last_region Last_state  Last_city  Customer_Value  \
# 9973     20130222        West    Gujarat      Surat       14786.600
# 9974     20130319        West    Gujarat      Surat       20696.900
# 9975     20120524        West    Gujarat      Surat       16858.099
# 9976     20130114       South  Telangana  Hyderabad       12863.000
# 9977     20120121        West    Gujarat      Surat         198.000
#
#       Buy_Times  Points_Earned  Points_Redeemed
# 9973         12          337.0            300.0
# ...

# %%
dup
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 9973     88092811      M    20120116         West         Gujarat
# 9974     84750517      F    20120119         West         Gujarat
# 9975      5686217      M    20120118         West     Maharashtra
# 9976     63669926      M    20120118        South       Telangana
# 9977     90964885      M    20120121         West         Gujarat
# 9978     87989417      M    20120127         West         Gujarat
# 9979      6005239      M    20120129         East     West Bengal
# 9980     91066310      M    20120130         West         Gujarat
# 9981       414338      M    20120131         West         Gujarat
# 9982      9144258      M    20120130        South      Tamil Nadu
# 9983     91076263      F    20120130         East     West Bengal
# 9984     85012902      M    20120201         West         Gujarat
# 9985     14762484      M    20120131        North  Madhya Pradesh
# ...

# %%
dup.tail()
# Out:
#       Customer_ID Gender  First_Date First_region    First_state First_city  \
# 9995     50093138      M    20120208        North  Uttar Pradesh       Agra
# 9996     92763145      M    20120209        South      Telangana  Hyderabad
# 9997     73839417      M    20120210        South      Karnataka  Bangalore
# 9998     69606859      M    20120215        North  Uttar Pradesh    Lucknow
# 9999    113292109      M    20120217         West    Maharashtra     Mumbai
#
#       Recent_Date Last_region     Last_state  Last_city  Customer_Value  \
# 9995     20121114       North  Uttar Pradesh       Agra         13818.6
# 9996     20130319       South      Telangana  Hyderabad         13016.5
# 9997     20130216       South      Karnataka  Bangalore         44057.9
# 9998     20120215       North  Uttar Pradesh    Lucknow          1116.0
# 9999     20120217        West    Maharashtra     Mumbai          1222.0
#
#       Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
#unique subsets

# %%
uniq=customer[customer.duplicated()==False]

# %%
uniq
# Out:
#       Customer_ID Gender  First_Date First_region    First_state  \
# 0       129609144      M    20130130         West        Gujarat
# 1       129627580      M    20130129        North          Delhi
# 2       130363481      M    20130221         West        Gujarat
# 3        49817480      M    20130222         West    Maharashtra
# 4       126343829      F    20130301        North          Delhi
# ...           ...    ...         ...          ...            ...
# 9968     60082781      M    20120115        North        Haryana
# 9969     88068705      M    20120116         West        Gujarat
# 9970      5599557      F    20120115         West        Gujarat
# 9971      7956527      F    20120115        North          Delhi
# 9972     10184222      M    20120116        North  Uttar Pradesh
#
#             First_city  Recent_Date Last_region     Last_state  \
# 0                Surat     20130216        West        Gujarat
# ...

# %%
uniq.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
uniq.tail()
# Out:
#       Customer_ID Gender  First_Date First_region    First_state First_city  \
# 9968     60082781      M    20120115        North        Haryana    Gurgaon
# 9969     88068705      M    20120116         West        Gujarat      Surat
# 9970      5599557      F    20120115         West        Gujarat     Rajkot
# 9971      7956527      F    20120115        North          Delhi      Delhi
# 9972     10184222      M    20120116        North  Uttar Pradesh     Kanpur
#
#       Recent_Date Last_region     Last_state  Last_city  Customer_Value  \
# 9968     20120220       North  Uttar Pradesh  Ghaziabad      3281.90100
# 9969     20120704        West        Gujarat      Surat     10996.00000
# 9970     20130330        West        Gujarat     Rajkot     74662.77636
# 9971     20130222       North          Delhi      Delhi     66082.19900
# 9972     20121014       North  Uttar Pradesh     Kanpur      2031.00100
#
#       Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
uniq.shape
# Out:
# (9973, 14)

# %%
uniq.describe()
# Out:
#         Customer_ID    First_Date   Recent_Date  Customer_Value    Buy_Times  \
# count  9.973000e+03  9.973000e+03  9.973000e+03    9.937000e+03  9973.000000
# mean   8.353205e+07  2.012200e+07  2.012537e+07    1.253969e+04     5.474882
# std    4.804282e+07  3.427692e+03  4.744472e+03    6.554889e+04    11.689041
# min    5.850000e+02  2.012010e+07  2.012010e+07    0.000000e+00     1.000000
# 25%    3.617439e+07  2.012023e+07  2.012082e+07    1.490000e+03     1.000000
# 50%    1.147126e+08  2.012070e+07  2.012122e+07    3.958800e+03     2.000000
# 75%    1.216379e+08  2.012111e+07  2.013030e+07    1.109350e+04     6.000000
# max    1.324735e+08  2.013033e+07  2.013033e+07    5.098715e+06   586.000000
#
#        Points_Earned  Points_Redeemed
# count    9952.000000     9.961000e+03
# mean      528.411475     5.833931e+02
# std      1862.745367     1.523336e+04
# min         0.000000     0.000000e+00
# 25%        65.000000     0.000000e+00
# 50%       195.000000     0.000000e+00
# ...

# %%
#create data set with a list  of customers whose customer value greater than 10000

# %%
list=customer[customer.Customer_Value>=1000]

# %%
list
# Out:
#       Customer_ID Gender  First_Date First_region    First_state  \
# 0       129609144      M    20130130         West        Gujarat
# 1       129627580      M    20130129        North          Delhi
# 3        49817480      M    20130222         West    Maharashtra
# 4       126343829      F    20130301        North          Delhi
# 5         8223758      F    20130314         West        Gujarat
# ...           ...    ...         ...          ...            ...
# 9995     50093138      M    20120208        North  Uttar Pradesh
# 9996     92763145      M    20120209        South      Telangana
# 9997     73839417      M    20120210        South      Karnataka
# 9998     69606859      M    20120215        North  Uttar Pradesh
# 9999    113292109      M    20120217         West    Maharashtra
#
#             First_city  Recent_Date Last_region     Last_state  \
# 0                Surat     20130216        West        Gujarat
# ...

# %%
#6.	In customer table, create a new variable called “customer value segment” using customer value as follows.
#-  - High Value Segment - > 25000  
#-	Medium Value Segment – Between 10000 and 25000  
#-	Low Value Segment – less than or equal to 10000

# %%
def Cust_value(x):
    if x>25000:
        return 'High value Segment'
    elif x>10000 and x<=25000:
        return 'Low value Segment'
    else:
        return 'Low value segment'

# %%
list=customer['Customer_Value_Segment']=customer['Customer_Value'].apply(Cust_value)

# %%
list.head()
# Out:
# 0    Low value segment
# 1    Low value segment
# 2    Low value segment
# 3    Low value segment
# 4    Low value segment
# Name: Customer_Value, dtype: object

# %%
customer.Customer_Value_Segment.value_counts()
# Out:
# Low value segment     7277
# Low value Segment     1605
# High value Segment    1118
# Name: Customer_Value_Segment, dtype: int64

# %%
#7.	Create variables “average revenue per trip” and “balance points” in the customer data set

# %%
customer['Average_Revenue_per_trip']=customer.Customer_Value/customer.Buy_Times

# %%
customer
# Out:
#       Customer_ID Gender  First_Date First_region    First_state  \
# 0       129609144      M    20130130         West        Gujarat
# 1       129627580      M    20130129        North          Delhi
# 2       130363481      M    20130221         West        Gujarat
# 3        49817480      M    20130222         West    Maharashtra
# 4       126343829      F    20130301        North          Delhi
# ...           ...    ...         ...          ...            ...
# 9995     50093138      M    20120208        North  Uttar Pradesh
# 9996     92763145      M    20120209        South      Telangana
# 9997     73839417      M    20120210        South      Karnataka
# 9998     69606859      M    20120215        North  Uttar Pradesh
# 9999    113292109      M    20120217         West    Maharashtra
#
#             First_city  Recent_Date Last_region     Last_state  \
# 0                Surat     20130216        West        Gujarat
# ...

# %%
customer['Balance_Points']=customer.Points_Earned-customer.Points_Redeemed

# %%
customer.shape
# Out:
# (10000, 17)

# %%
#	Calculate percentage of sales by each last city, state and region.

# %%
customer.groupby(['Last_region','Last_state','Last_city']).sum()['Customer_Value'].apply(lambda x:x/customer.Customer_Value.sum())*100
# Out:
# Last_region  Last_state   Last_city
# East         Assam        Guwahati            1.557344
#              Bihar        Begusarai           0.020559
#                           Bhagalpur           0.002230
#                           Katihar             0.046883
#                           Patna               0.185101
#                                                 ...
# West         Maharashtra  Navi Mumbai         0.010617
#                           Pimpri-Chinchwad    3.314578
#                           Thane               0.237204
#                           Ulhasnagar          0.005667
#                           Vasai-Virar         0.085952
# Name: Customer_Value, Length: 116, dtype: float64

# %%
# What is the count of customers, average number of purchases and average purchase transaction value by last state and city.

# %%
customer.groupby(['Last_state','Last_city']).agg({'Customer_ID':'count','Customer_Value':'mean','Buy_Times':'mean'})
# Out:
#                                 Customer_ID  Customer_Value  Buy_Times
# Last_state     Last_city
# Andhra Pradesh Guntur                     1        0.000000   3.000000
#                Kurnool                    1     3113.499000   4.000000
#                Tirupati                   2     9250.000000   6.000000
#                Vijayawada                20    24670.100100  10.100000
#                Visakhapatnam            117    11135.137740   4.666667
# ...                                     ...             ...        ...
# West Bengal    Kolkata                  543    12853.575301   6.046041
#                North Dumdum               3     9514.733333   3.333333
#                Panihati                   1     6923.003000   7.000000
#                Rajpur Sonarpur            2     1083.000000   2.000000
#                Siliguri                   1    10379.000000   4.000000
#
# [116 rows x 3 columns]
